# %% [markdown]
# # linear regression

# %% [markdown]
# <font color="red">Regression</font>
# <br>
# regression analayis is a from of predictive modeling techniques which investigates the relationship between a dependent and indepentened variable
#
# A resgression analysis involves graphing aline over od set os data points that must  closely fits the overall shape of the data or regression show the change the in a depnted value on y-axis and the change of explanatory variable of x=-axis
#
# <font color="red">The users of Regression</font>
# <br>
# The three major user of regression analysis
# They are
# - Determining the strenght of predictors
# - forecasting an effect , and
# - trend forcasting

# %% [markdown]
# <font color="red">Linear Regression</font>
# <br>
# <font color="blue">selection criteria </font>
# - classification and regression capabilities Regression model predict the continuous variable such as the sales mode on a day in  a shop or predicit the temperature of city their reliance on a polynomial like a straight line to fit a data set pases a real challenge when it come towords building a classification capability
#
# ***let imagine that you fit a line with the train points that you have to imaginr you add some more data points to it . but in order to fit it we need to change the model or you have to change thr existing model . That you have to cahnge the threshold itself.So this will happen with each new data point that you add into the model . Hence the linear regression is not good for classfication model ***
# - Data Quality
# - computational Complexity(it take Obig(n))
# - Comprehensive and transparency

# %% [markdown]
# <font color="red"> **Where is linear Regression  used ?**</font>

# %% [markdown]
# - evaluating trends and sales estimates well linear regression can be used in business to evaluate trends and make estimate or focused
# - Analyzing the impact of price changes
# - Assessment of risk in financial servies and insurance domain!

# %% [markdown]
# **Dataset**
# Let’s looks at our dataset first. I have taken a simple dataset for an easy explanation. **Years of Experience vs Salary.**
#
# We want to predict the salary of the person based on their years of experience?

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# In the given dataset, we have Exp vs Salary. Now, we want to predict the salary for 3.5 years of experience? Let’s see how to predict that?

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# c →y-intercept → What is the value of y when x is zero?
# The regression line cuts the y-axis at the y-intercept.
#
# Y → Predicted Y value for the given X value
#
# Let’s calculate m and c.
#
# m is also known as regression co-efficient. It tells whether there is a positive correlation between the dependent and independent variables. A positive correlation means when the independent variable increases, the mean of the dependent variable also increases.

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# The Regression coefficient is defined as the covariance of x and y divided by the variance of the independent variable, x.
#
# Variance → How far each number in the dataset is from the mean.
# x̄ → mean of x
# ȳ → mean of y
#
# Covariance →It’s a measure of the relationship between two variables.

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# Covariance =( Σ [ (xi — x̅ )(yi — ȳ) ])/n=529.0740741
#
# Variance =(Σ [ (xi — x̅ )²])/n= 1.509876543
#
# m= Covariance /Variance =529.0740741/1.509876543=350.4088307
#
# m=350.4088307

# %% [markdown]
# Now to calculate intercept c
#
# y=mx+c
# c=y-mx
# Apply mean y (ȳ) and mean x (x̅)in the equation and calculate c
#
# c= 1683.33333-(350.4088307*2.7111)
# c=733.3360589
#
# After calculating m and c, now we can do predictions.
#
# Let’s predict the salary of a person having 3.5 years of experience.
#
# y=mx+c
# m=350.4088307
# c=733.3360589
#
# y predict = (350.4088307 * 3.5) + 733.3360589 = 1959.766966
#
# The predicted y value for x=3.5 is 1959.766966

# %% [markdown]
# **Performance Evaluation**
#
# To evaluate how good our regression model is, we can use the following metrics.
#
# **SSE-Sum of Squares Error**
#
# The error or residual is the difference between the actual value and the predicted value. The sum of all errors can cancel out since it can contain negative signs and give zero. So, we square all the errors and sum it up. The line which gives us the least sum of squared errors is the best fit.
#
# The line of best fit always goes through x̅ and ȳ.
#
# In Linear Regression, the line of best fit is calculated by minimizing the error(the distance between data points and the line).
#
# **Sum of Squares Errors** is also known as **Residual error or Residual sum of squares**

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# **SSR Sum of Squares due to Regression**
# <br>
# SSR is also known as Regression Error or Explained Error.
# It is the sum of the differences between the predicted value and the mean of the dependent variable ȳ

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# **SST Sum of Squares Total**
#
# SST/Total Error = Sum of squared errors + Regression Error.
#
# Total Error or Variability of the data set is equal to the variability explained by the regression line (Regression Error) plus the unexplained variability (SSE) known as error or residuals.

# %% [markdown]
# ![7.png](attachment:7.png)

# %% [markdown]
# Explained Error or Variability → SSR
#
# Unexplained Error → SSE

# %% [markdown]
# ![8.png](attachment:8.png)

# %% [markdown]
# **MSE → Mean Squared Error**
#
# MSE is the average of the squared difference between the actual and predicted values of the data points.

# %% [markdown]
# ![9.png](attachment:9.png)

# %% [markdown]
# **RMSE -Root Mean Squared Error**
#
# RMSE is a measure of how spread out these residuals are. In other words, it tells you how concentrated the data is around the line of best fit.
# RMSE is calculated by taking the square root of MSE.
#
# **Interpretation of RMSE:**
# RMSE is interpreted as the standard deviation of unexplained variance(MSE).
# RMSE contains the same units as the dependent variable.
# Lower values of RMSE indicates a better fit.
#
# **Coefficient of Correlation (r)**
#
# Before building the model, have to identify good predictors. The coefficient of Correlation (r) is used to determine the strength of the relationship between two variables. It will help to identify good predictors.
#
# **Formula:**

# %% [markdown]
# ![10.png](attachment:10.png)

# %% [markdown]
# ![11.png](attachment:11.png)

# %% [markdown]
# The value of r **range from -1 to 1.**
#
# -1 indicates a negative correlation which means when x increases y decreases.
#
# +1 indicates a positive correlation which means both x and y travels in the same direction.
#
# 0 or close to 0 means no correlation.

# %% [markdown]
# **R²( R square )→ Coefficient of determination**
#
# The coefficient of determination → This metric is used after building the model, to check how reliable the model is.
#
# R² →It is equal to the variance explained by regression (Regression Error or SSR) divided by Total variance in y (SST)
#
# R² → It describes how much of the total variance in y is explained by our model.
#
# If Error(unexplained error or SSE)<Variance (SST) means the model is good.
#
# The best fit is the line in which unexplained error (SSE) is minimized.
#
# R² values range from 0 to 1.
#
# 0 → indicates Poor model
# 1 or close to 1 → indicates the Best model

# %% [markdown]
# ![12.png](attachment:12.png)

# %% [markdown]
# **Calculating MSE, RMSE, R² in our dataset**

# %% [markdown]
# ![13.png](attachment:13.png)

# %%
# lets code it...bro
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read the data using the pandas
df=pd.read_csv("headbrain.csv")

# %%
# TO know the shape of the data
df.shape
# Out:
# (237, 4)

# %%
df.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
# collecting  the x and y data
X=df["Head Size(cm^3)"].values
Y=df["Brain Weight(grams)"].values

# %%
#mean od x and y  ## x̅ and  ȳ
mean_x=np.mean(X)
mean_y=np.mean(Y)

# %%
#total number of values
n=len(X)

# %%
n
# Out:
# 237

# %%
# using the formula 
num=0
denum=0
for i in range(n):
    num+=(X[i]-mean_x)*(Y[i]-mean_y)
    denum+=(X[i]-mean_x)**2
m=num/denum
c=mean_y - (m * mean_x)
print("the m value :"+ str(m),"the value of c :"+str(c))
# Out:
# the m value :0.26342933948939945 the value of c :325.57342104944223

# %%
#ploting values and regression line
max_x = np.max(X)+100
min_x=np.min(X)-100

# %%
#calculating line v al ue x and y
x=np.linspace(min_x,max_x,1000)
y=m*x+c

# %%
# plotting the line
plt.plot(x,y,color="red",label="resgression line")

# %%
# plotting the line
plt.plot(x,y,color="red",label="resgression line")
#plotting scatting points
plt.scatter(X,Y,color="blue",label="data")
plt.xlabel("head size")
plt.ylabel("brain size")
plt.legend()
plt.show()

# %%
#ssr/sst
sst=0
ssr=0
for i in range(n):
    y_pred=m*X[i]+c
    sst+=(Y[i] - mean_y)**2
    ssr=(Y[i] - y_pred)**2
 
    
# r2=ssr/sst
# #by using the r2=ssr/sst the range was more that 1 so that we are useing the r2=1-(ssr/sst)
# print(r2)  #349.6823531478277
r2= 1-(ssr/sst)
print(r2)
# Out:
# 0.9971402617518498

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X=X.reshape((n,1))

# %%
reg=LinearRegression()
reg=reg.fit(X,Y)
Y_pred=reg.predict(X)

# %%
r2_score=reg.score(X,Y)
print(r2_score)
# Out:
# 0.639311719957

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               237 non-null    int64
#  1   Age Range            237 non-null    int64
#  2   Head Size(cm^3)      237 non-null    int64
#  3   Brain Weight(grams)  237 non-null    int64
# dtypes: int64(4)
# memory usage: 7.5 KB

# %%
df.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
X=df.iloc[:,:3]

# %%
X
# Out:
#      Gender  Age Range  Head Size(cm^3)
# 0         1          1             4512
# 1         1          1             3738
# 2         1          1             4261
# 3         1          1             3777
# 4         1          1             4177
# ..      ...        ...              ...
# 232       2          2             3214
# 233       2          2             3394
# 234       2          2             3233
# 235       2          2             3352
# 236       2          2             3391
#
# [237 rows x 3 columns]

# %%
Y=df.iloc[:,-1]

# %%
Y
# Out:
# 0      1530
# 1      1297
# 2      1335
# 3      1282
# 4      1590
#        ...
# 232    1110
# 233    1215
# 234    1104
# 235    1170
# 236    1120
# Name: Brain Weight(grams), Length: 237, dtype: int64

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
lin=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25)

# %%
lin.fit(X,Y)
# Out:
# LinearRegression()

# %%
print(lin.score(X_test, y_test))
# Out:
# 0.6669167588620417

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [35], in <cell line: 3>()
#       1 from mlxtend.evaluate import bias_variance_decomp
#       2 # Get Bias and Variance - bias_variance_decomp function
# ----> 3 avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
#       4 lin,X_train, X_test, y_train, y_test,
#       5 )
#       6 # Display Bias and Variance
#       7 print(f'Average Expected Loss: {round(avg_expected_loss, 4)}n')
#
# File ~\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:86, in bias_variance_decomp(estimator, X_train, y_train, X_test, y_test, loss, num_rounds, random_seed, **fit_params)
#      84 for ary in (X_train, y_train, X_test, y_test):
#      85     if hasattr(ary, "loc"):
# ---> 86         raise ValueError(
#      87             "The bias_variance_decomp does not "
#      88             "support pandas DataFrames yet. "
#      89             "Please check the inputs to "
#      90             "X_train, y_train, X_test, y_test. "
#      91             "If e.g., X_train is a pandas "
#      92             "DataFrame, try passing it as NumPy array via "
#      93             "X_train=X_train.values."
#      94         )
#      96 rng = np.random.RandomState(random_seed)
#      98 if loss == "0-1_loss":
#
# ValueError: The bias_variance_decomp does not support pandas DataFrames yet. Please check the inputs to X_train, y_train, X_test, y_test. If e.g., X_train is a pandas DataFrame, try passing it as NumPy array via X_train=X_train.values.
