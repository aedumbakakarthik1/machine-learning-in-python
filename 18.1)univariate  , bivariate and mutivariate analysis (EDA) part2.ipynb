# %%
df=pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
active_imports()
# Out:
# import pandas as pd
# ['import pandas as pd']

# %% [markdown]
#  # univariate

# %%
df_Setosa=df.loc[df["variety"]=="Setosa"]

# %%
df_Virginica=df.loc[df["variety"]=="Virginica"]
df_Vericolor=df.loc[df["variety"]=="Vericolor"]

# %%
plt.plot(df["sepal.width"],np.zeros_like(df["sepal.width"]))

# %%
plt.plot(df_Setosa["sepal.width"],np.zeros_like(df_Setosa["sepal.width"]))

# %%
plt.plot(df_Setosa["petal.length"],np.zeros_like(df_Setosa["petal.length"]),"o")
plt.plot(df_Virginica["petal.length"],np.zeros_like(df_Virginica["petal.length"]),"o")
plt.plot(df_Vericolor["petal.length"],np.zeros_like(df_Vericolor["petal.length"]),"o")
plt.show()

# %%
plt.plot(df_Virginica["petal.length"],np.zeros_like(df_Virginica["petal.length"]),"o")

# %%
plt.plot(df_Vericolor["petal.length"],np.zeros_like(df_Vericolor["petal.length"]),"o")

# %% [markdown]
# # bivariate

# %%
sns.FacetGrid(df,hue="variety",size=5).map(plt.scatter,"sepal.length","sepal.width").add_legend()
# Out:
# C:\Users\aedum\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df,hue="variety",size=5).map(plt.scatter,"petal.length","petal.width").add_legend()
# Out:
# C:\Users\aedum\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # mutivariate  analysis

# %%
sns.pairplot(df,hue="variety",size=5)
# Out:
# C:\Users\aedum\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
