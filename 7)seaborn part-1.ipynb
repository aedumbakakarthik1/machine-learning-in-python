# %% [markdown]
# # Seaborn
#
# ## distribution plots
# - distplot
# - joinplot
# - pairplot
#
# Practise problems on IRIS Dataset

# %%
import seaborn as sns

# %%
df=sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(max(df["tip"]))
print(max(df["size"]))
# Out:
# 10.0
# 6

# %% [markdown]
# # Correlation with heatmap
# A correlation heatmap uses colored cell , typically in momochromathic scale , to a 2d correlation matix (table) between two discrate dimensions or events types . it is very import in feature selection
#
# - correlation always apply to int are float valuse  and not for category value
#
# - the range of the correlaton in -1 to 1 only

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# abive we jusr seen in number format if we need the picture format we use below one

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Join Plot
#
# A Join plot allows to study the relationship between 2 numeric variables . the crentral chat displays their correlation . it is usually a scatterplot ,a haxbin plot , a 2D histogram or a 2D density plot

# %%
sns.jointplot(x="tip",y="total_bill",data=df,kind="hex",color="red")

# %%
sns.jointplot(x="tip",y="total_bill",data=df,kind='scatter')

# %%
sns.jointplot(x="tip",y="total_bill",data=df,kind='reg',color="darkblue")

# %%
sns.jointplot(x="tip",y="total_bill",data=df,kind='kde',hue="size")

# %% [markdown]
# # pair plot
#
# A "pair plot" is also know as a scatterplot , in which ane variable in the same data row is matched with another variable's values , like this : Pair plot are just elaboration in this , showing all variables paired with all the orther variables

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,kind="reg")

# %%
sns.pairplot(df,hue="sex",kind="reg")

# %% [markdown]
# # Dist plot
# Dist plot helps us to check the distribution of the columns feature

# %%
sns.distplot(df["tip"])
# Out:
# C:\Users\aedum\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(df["tip"],kde=False,bins=10)
# Out:
# C:\Users\aedum\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
#  # example

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.corr()
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x="sepal.length",y="petal.length",data=df,kind="hex")

# %%
sns.jointplot(x="sepal.length",y="petal.length",data=df,kind="reg")

# %%
sns.pairplot(df)

# %%
sns.distplot(df["sepal.length"])
# Out:
# C:\Users\aedum\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal.length', ylabel='Density'>
